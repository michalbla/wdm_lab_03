# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Wprowadzenie-do-Pandas-i-Seaborn" data-toc-modified-id="Wprowadzenie-do-Pandas-i-Seaborn-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Wprowadzenie do Pandas i Seaborn</a></span><ul class="toc-item"><li><span><a href="#Pandas" data-toc-modified-id="Pandas-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Pandas</a></span></li><li><span><a href="#Series-i-DataFrame" data-toc-modified-id="Series-i-DataFrame-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Series i DataFrame</a></span></li><li><span><a href="#Series" data-toc-modified-id="Series-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Series</a></span></li><li><span><a href="#DataFrame" data-toc-modified-id="DataFrame-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>DataFrame</a></span><ul class="toc-item"><li><span><a href="#Indeksowanie-tablic-DataFrame" data-toc-modified-id="Indeksowanie-tablic-DataFrame-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Indeksowanie tablic DataFrame</a></span></li><li><span><a href="#Operacje-arytmetyczne-i-funkcje-NumPy" data-toc-modified-id="Operacje-arytmetyczne-i-funkcje-NumPy-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Operacje arytmetyczne i funkcje NumPy</a></span></li><li><span><a href="#Funkcje-statystyczne" data-toc-modified-id="Funkcje-statystyczne-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Funkcje statystyczne</a></span></li><li><span><a href="#Ćwiczenie" data-toc-modified-id="Ćwiczenie-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Ćwiczenie</a></span></li><li><span><a href="#Import-danych-z-plików-CSV" data-toc-modified-id="Import-danych-z-plików-CSV-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>Import danych z plików CSV</a></span></li><li><span><a href="#Informacje-o-nazwie-i-typie-zmiennych-(kolumn)" data-toc-modified-id="Informacje-o-nazwie-i-typie-zmiennych-(kolumn)-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>Informacje o nazwie i typie zmiennych (kolumn)</a></span></li><li><span><a href="#Podstawowe-statystyki-opisowe:-describe()" data-toc-modified-id="Podstawowe-statystyki-opisowe:-describe()-1.4.7"><span class="toc-item-num">1.4.7&nbsp;&nbsp;</span>Podstawowe statystyki opisowe: describe()</a></span></li><li><span><a href="#Korelacje" data-toc-modified-id="Korelacje-1.4.8"><span class="toc-item-num">1.4.8&nbsp;&nbsp;</span>Korelacje</a></span></li><li><span><a href="#Wykresy-w-Pandas" data-toc-modified-id="Wykresy-w-Pandas-1.4.9"><span class="toc-item-num">1.4.9&nbsp;&nbsp;</span>Wykresy w Pandas</a></span></li><li><span><a href="#Grupowanie-danych" data-toc-modified-id="Grupowanie-danych-1.4.10"><span class="toc-item-num">1.4.10&nbsp;&nbsp;</span>Grupowanie danych</a></span></li></ul></li><li><span><a href="#Pakiet-Seaborn" data-toc-modified-id="Pakiet-Seaborn-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Pakiet Seaborn</a></span><ul class="toc-item"><li><span><a href="#Wykres-rozkładu-danych" data-toc-modified-id="Wykres-rozkładu-danych-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Wykres rozkładu danych</a></span></li><li><span><a href="#Wykresy-relacji-dwóch-zmiennych" data-toc-modified-id="Wykresy-relacji-dwóch-zmiennych-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Wykresy relacji dwóch zmiennych</a></span></li><li><span><a href="#pairplot" data-toc-modified-id="pairplot-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>pairplot</a></span></li><li><span><a href="#Ćwiczenie" data-toc-modified-id="Ćwiczenie-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Ćwiczenie</a></span></li><li><span><a href="#regplot()---wykres-z-regresja-liniową" data-toc-modified-id="regplot()---wykres-z-regresja-liniową-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>regplot() - wykres z regresja liniową</a></span></li><li><span><a href="#Korelacje-(heatmp)" data-toc-modified-id="Korelacje-(heatmp)-1.5.6"><span class="toc-item-num">1.5.6&nbsp;&nbsp;</span>Korelacje (heatmp)</a></span></li><li><span><a href="#Wykresy-zmiennych-dyskretnych:" data-toc-modified-id="Wykresy-zmiennych-dyskretnych:-1.5.7"><span class="toc-item-num">1.5.7&nbsp;&nbsp;</span>Wykresy zmiennych dyskretnych:</a></span></li></ul></li><li><span><a href="#Zadanie:-choroby-serca" data-toc-modified-id="Zadanie:-choroby-serca-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Zadanie: choroby serca</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Wprowadzenie do Pandas i Seaborn

# %% [markdown]
# ## Pandas
#
# Pakiet Pandas udostępnia dwa obiekty służące do wygodnego przechowywania danych i ułatwiających manipulowanie danymi:
# * **Series** to obiekt reprezentujący jednowymiarową tablicę danych
# * **DataFrame** to dwu-wymiarowa tabela danych (zbiór obiektów series)
#
# Pandas WWW: <https://pandas.pydata.org/>
# Pandas Tutorial: <https://pandas.pydata.org/docs/getting_started/intro_tutorials/index.html>

# %% [markdown]
# ## Series i DataFrame

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Series
#
# Seria jest obiektem reprezentującym jednowymiarową tablicę danych o indeksowanych elementach. Seria może być utworzona z dowolnej kolekcji liczb: krotki, listy, tablicy `numpy` a nawet ze słownika. Obiekt `Series` udostępnia wiele metod pozwalających operować na danych w serii, zawiera też  metody do wizualizowania danych. Dodatkowo, wiele funkcji z pakietu `numpy` może być użytych na tym obiekcie, jeżeli tylko seria zawiera liczby.

# %%
import pandas as pd

s = pd.Series( [3.1, 2.4, -1.7, 0.2, -2.9, 4.5] )   # seria utworzona z listy liczb
print(s)
# Out:
# 0    3.1
# 1    2.4
# 2   -1.7
# 3    0.2
# 4   -2.9
# 5    4.5
# dtype: float64

# %%
s = pd.Series([3.1, 2.4, -1.7, 0.2, -2.9, 4.5]) 

print('Values=', s.values, type(s.values))     # wartości serii (obiekt ndarray z NumPy)
print('Index=', s.index)                       # indeksy serii 
print('Pierwszy element:', s[0])               # indeksowanie elementów
# Out:
# Values= [ 3.1  2.4 -1.7  0.2 -2.9  4.5] <class 'numpy.ndarray'>
# Index= RangeIndex(start=0, stop=6, step=1)
# Pierwszy element: 3.1

# %% [markdown]
# W odróżnieniu do tablic indeksami nie muszą być liczby całkowite.

# %%
import numpy as np

s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'], name='Zmienna')
s
# Out:
# a    1.045568
# b    1.073810
# c   -1.798663
# d   -0.397390
# e   -0.477020
# Name: Zmienna, dtype: float64

# %%
print('Values=', s.values)   # wartości, to tablica numpy
print('Index=', s.index)     # indeksy
# Out:
# Values= [ 1.04556783  1.07380951 -1.79866265 -0.39738994 -0.47701963]
# Index= Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
print(s['a'])     # indeksowanie za pomocą napisów
print(s[0])       # indeksowanie liczbami całkowitymi nadal działa
# Out:
# 1.0455678279108895
# 1.0455678279108895
# C:\Users\Michal\AppData\Local\Temp\ipykernel_12732\4067174233.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[0])       # indeksowanie liczbami całkowitymi nadal działa

# %% [markdown]
# Obiekt Series w wielu sytuacjach zachowuje się podobnie do tablic NumPy.
# W podobny sposób indeksuje się elementy serii, z tą różnicą, że przekroje również dotyczą indeksów.

# %%
s = pd.Series([1.2, 2.5, -2.2, 3.1, -0.8], index = ['pn','wt','śr','czw','pt'], name='Zmienna')
s
# Out:
# pn     1.2
# wt     2.5
# śr    -2.2
# czw    3.1
# pt    -0.8
# Name: Zmienna, dtype: float64

# %%
s[1:3]          # przekrój serii (elementy od 1 do 2)
# Out:
# wt    2.5
# śr   -2.2
# Name: Zmienna, dtype: float64

# %%
s['wt':'czw']    # elementy od wt do czw (zauważ, że ostatni element 'czw' też jest włączony)
# Out:
# wt     2.5
# śr    -2.2
# czw    3.1
# Name: Zmienna, dtype: float64

# %% [markdown]
# Gdy seria zawiera wartości numeryczne to można wykonywać na niej operacje arytmetyczne i funkcje NumPy

# %%
s = s +  4
s
# Out:
# pn     5.2
# wt     6.5
# śr     1.8
# czw    7.1
# pt     3.2
# Name: Zmienna, dtype: float64

# %%
s = np.sqrt(s)
s
# Out:
# pn     2.280351
# wt     2.549510
# śr     1.341641
# czw    2.664583
# pt     1.788854
# Name: Zmienna, dtype: float64

# %% [markdown]
# ## DataFrame
#
# Obiekt `DataFrame` reprezentuje 2-wymiarową tabelę danych, która posiada indeksowane kolumny oraz wiersze.
# Każda kolumna to obiekt Series. Kolumna reprezentuje zmienną i może zawierać elementy różnego typu (liczby, wartości kategoryczne, napisy, serie czasowe, itd.).
#
# <div>
# <img src="attachment:4f98748b-7f54-4401-852b-369c5ffa1c7e.png" width="600">
# </div>
#
# Tablica DataFrame posiada wiele przydatnych metod ułatwiających operowanie danymi, wyznaczanie statystyk i sporządzenie wykresów.
#
# Zobacz: <https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html>

# %% [markdown]
# Tworzenie tablic DataFrame (np. z tablicy numpy)

# %%
df = pd.DataFrame(np.random.rand(4,3), columns=['zmienna 1', 'zmienna 2', 'zmienna 3'])
df
# Out:
#    zmienna 1  zmienna 2  zmienna 3
# 0   0.237623   0.589228   0.139858
# 1   0.838790   0.252953   0.113787
# 2   0.028951   0.329605   0.169632
# 3   0.821048   0.878066   0.076050

# %% [markdown]
# Własność ``values`` zwraca tablicę w reprezentacji Numpy

# %%
print('Values=', df.values)
print('Typ', type(df.values))
# Out:
# Values= [[0.23762325 0.58922833 0.13985753]
#  [0.83879015 0.25295325 0.11378713]
#  [0.02895056 0.32960536 0.16963237]
#  [0.82104826 0.8780663  0.07604955]]
# Typ <class 'numpy.ndarray'>

# %%
print('Index=',  df.index)      
print('Columns:', df.columns)
# Out:
# Index= RangeIndex(start=0, stop=4, step=1)
# Columns: Index(['zmienna 1', 'zmienna 2', 'zmienna 3'], dtype='object')

# %% [markdown]
# Kolumny (zmienne) indeksowane są za pomocą nazw zmiennych

# %%
df['zmienna 2']   # wynikiem jest seria
# Out:
# 0    0.589228
# 1    0.252953
# 2    0.329605
# 3    0.878066
# Name: zmienna 2, dtype: float64

# %% [markdown]
# Kolumna tabeli `DataFrame` jest obiektem `Series`

# %%
type(df['zmienna 2'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Dodawanie nowych kolumn w tabeli przypomina dodawanie nowych elementów do słownika

# %%
df['rok'] = 2021                              # dodanie kolumny ze stałą wartością
df
# Out:
#    zmienna 1  zmienna 2  zmienna 3   rok
# 0   0.237623   0.589228   0.139858  2021
# 1   0.838790   0.252953   0.113787  2021
# 2   0.028951   0.329605   0.169632  2021
# 3   0.821048   0.878066   0.076050  2021

# %%
df['x1'] = np.random.rand(4)     # dodawanie sekwencji wartosci
df['liczby'] = ['raz', 'dwa', 'trzy', 'cztery']
df
# Out:
#    zmienna 1  zmienna 2  zmienna 3   rok        x1  liczby
# 0   0.237623   0.589228   0.139858  2021  0.264751     raz
# 1   0.838790   0.252953   0.113787  2021  0.778196     dwa
# 2   0.028951   0.329605   0.169632  2021  0.453329    trzy
# 3   0.821048   0.878066   0.076050  2021  0.735690  cztery

# %% [markdown]
# Tworzenie nowej zmiennej jako funkcji wynikowej innych zmiennych

# %%
df['zm1+zm2'] = df['zmienna 1'] + df['zmienna 2']
df
# Out:
#    zmienna 1  zmienna 2  zmienna 3   rok        x1  liczby   zm1+zm2
# 0   0.237623   0.589228   0.139858  2021  0.264751     raz  0.826852
# 1   0.838790   0.252953   0.113787  2021  0.778196     dwa  1.091743
# 2   0.028951   0.329605   0.169632  2021  0.453329    trzy  0.358556
# 3   0.821048   0.878066   0.076050  2021  0.735690  cztery  1.699115

# %% [markdown]
# Wybór kilku zmiennych (indeksem jest lista zmiennych)

# %%
df[ ['rok', 'zmienna 1'] ]
# Out:
#     rok  zmienna 1
# 0  2021   0.237623
# 1  2021   0.838790
# 2  2021   0.028951
# 3  2021   0.821048

# %% [markdown]
# Wynik jest typu ``DataFrame``, otrzymujemy nowy widok tabeli

# %%
type(df[ ['zmienna 1', 'rok'] ])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Kolumna (seria) dostępna jest też poprzez własność obiektu ``DataFrame`` o tej samej nazwie co nazwa zmiennej

# %%
df.rok           # to samo co df['rok']
# Out:
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# Name: rok, dtype: int64

# %%
df.liczby[2:]
# Out:
# 2      trzy
# 3    cztery
# Name: liczby, dtype: object

# %% [markdown]
# ### Indeksowanie tablic DataFrame
#
# * atrybut `iloc[]` - indeksowanie za pomocą __liczb całkowitych__ (lub macierzy boolowskich) identycznie jak macierze `numpy`
# * atrybut `loc[]` - indeksowanie za pomocą etykiet (indeks, nazwy zmiennych) lub macierzy boolowskich

# %%
display(df)
# Out:
#    zmienna 1  zmienna 2  zmienna 3   rok        x1  liczby   zm1+zm2
# 0   0.237623   0.589228   0.139858  2021  0.264751     raz  0.826852
# 1   0.838790   0.252953   0.113787  2021  0.778196     dwa  1.091743
# 2   0.028951   0.329605   0.169632  2021  0.453329    trzy  0.358556
# 3   0.821048   0.878066   0.076050  2021  0.735690  cztery  1.699115

# %%
df.iloc[2]    # wiersz 3, wynikiem jest seria z elementów wiersza, elementy mogą być różnego typu
# Out:
# zmienna 1    0.028951
# zmienna 2    0.329605
# zmienna 3    0.169632
# rok              2021
# x1           0.453329
# liczby           trzy
# zm1+zm2      0.358556
# Name: 2, dtype: object

# %%
df.iloc[2 ,1]    # 3 wiersz, 2 kolumna,
# Out:
# 0.3296053647617664

# %% [markdown]
# Własność ``iloc``: indeksowanie tablicy jak w Numpy

# %%
display(df)
df.iloc[:, 2]   # trzecia kolumna tabeli -> wynikiem jest seria
# Out:
#    zmienna 1  zmienna 2  zmienna 3   rok        x1  liczby   zm1+zm2
# 0   0.237623   0.589228   0.139858  2021  0.264751     raz  0.826852
# 1   0.838790   0.252953   0.113787  2021  0.778196     dwa  1.091743
# 2   0.028951   0.329605   0.169632  2021  0.453329    trzy  0.358556
# 3   0.821048   0.878066   0.076050  2021  0.735690  cztery  1.699115
# 0    0.139858
# 1    0.113787
# 2    0.169632
# 3    0.076050
# Name: zmienna 3, dtype: float64

# %%
df.iloc[:2, 1:3]     # przekrój danych (wiersze 0,1,2 i kolumny 1,2) -> wynik DataFrame
# Out:
#    zmienna 2  zmienna 3
# 0   0.589228   0.139858
# 1   0.252953   0.113787

# %% [markdown]
# Własność ``loc``: indeksowanie nazwami zmiennych i kluczami indeksu

# %%
df.loc[2]    # gdy indeksy są liczbami to działa to analigicznie jak iloc[]
# Out:
# zmienna 1    0.028951
# zmienna 2    0.329605
# zmienna 3    0.169632
# rok              2021
# x1           0.453329
# liczby           trzy
# zm1+zm2      0.358556
# Name: 2, dtype: object

# %%
df.loc[:2]    # zauważ, że loc[] uwzględnia ostatni element zakresu
# Out:
#    zmienna 1  zmienna 2  zmienna 3   rok        x1 liczby   zm1+zm2
# 0   0.237623   0.589228   0.139858  2021  0.264751    raz  0.826852
# 1   0.838790   0.252953   0.113787  2021  0.778196    dwa  1.091743
# 2   0.028951   0.329605   0.169632  2021  0.453329   trzy  0.358556

# %%
df.loc[:2, 'rok':'x1']   # drugi wymiar to zmienne, można indeksować po nazwach
# Out:
#     rok        x1
# 0  2021  0.264751
# 1  2021  0.778196
# 2  2021  0.453329

# %%
df.loc[:2, ['rok', 'x1']]
# Out:
#     rok        x1
# 0  2021  0.264751
# 1  2021  0.778196
# 2  2021  0.453329

# %% [markdown]
# Filtrowanie za pomocą wyrażeń logicznych

# %%
df[ df['x1'] < 0.6 ]
# Out:
#    zmienna 1  zmienna 2  zmienna 3   rok        x1 liczby   zm1+zm2
# 0   0.237623   0.589228   0.139858  2021  0.264751    raz  0.826852
# 2   0.028951   0.329605   0.169632  2021  0.453329   trzy  0.358556

# %%
df[ (df.x1 < 0.6) | (df.liczby == "trzy") ]
# Out:
#    zmienna 1  zmienna 2  zmienna 3   rok        x1 liczby   zm1+zm2
# 0   0.237623   0.589228   0.139858  2021  0.264751    raz  0.826852
# 2   0.028951   0.329605   0.169632  2021  0.453329   trzy  0.358556

# %% [markdown]
# ###  Operacje arytmetyczne i funkcje NumPy
#
# Jeżeli tablica zawiera dane liczbowe to można na nich wykonywać operacje arytmetyczne oraz funkcje  `numpy`.

# %%
data = pd.DataFrame(np.random.rand(3, 2), columns=['x1', 'x2'])
data
# Out:
#          x1        x2
# 0  0.373354  0.922832
# 1  0.618311  0.925815
# 2  0.307703  0.205720

# %%
data + 4
# Out:
#          x1        x2
# 0  4.373354  4.922832
# 1  4.618311  4.925815
# 2  4.307703  4.205720

# %%
np.exp(data)
# Out:
#          x1        x2
# 0  1.452599  2.516408
# 1  1.855790  2.523925
# 2  1.360296  1.228410

# %% [markdown]
# ### Funkcje statystyczne
#
# ``mean()``, ``std()``, ``median()``, ``min()``, ``max()``, itd.
# * obliczane dla zmiennych (serii)
# * wynikiem jest seria, której indeksami są nazwy zmiennych

# %%
display(data)

data.min()
# Out:
#          x1        x2
# 0  0.373354  0.922832
# 1  0.618311  0.925815
# 2  0.307703  0.205720
# x1    0.307703
# x2    0.205720
# dtype: float64

# %% [markdown]
# ### Ćwiczenie
#
# Umieść dane z zadania z pierwszych zajęć ([Zadanie 1](https://github.com/IS-UMK/wdm_24_lab_01/)) w tablicy `DataFrame` i skorzystaj z operacji biblioteki Pandas do wyznaczenia współczynników `a` i `b` funkcji liniowej dopasowaenej metodą najmniejszych kwadratów.

# %%
x = [ 8, 2, 11, 6, 5, 4, 12, 9, 6, 1 ]
y = [ 3, 10, 3, 6, 8, 12, 1, 4, 9, 14 ]

# %% [markdown]
# ### Import danych z plików CSV
#
# ![image.png](attachment:image.png)

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Informacje o nazwie i typie zmiennych (kolumn)

# %%
tips.info()     # informacje o zmiennych
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips.head()     # podgląd początku tabeli
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Podstawowe statystyki opisowe: describe()

# %%
tips.describe()   # domyślnie wynik tylko dla zmiennych liczbowych (ciągłych)
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# Dla zmiennych kategorycznych (nie liczbowych, typ ``object``) przydatne są inne statystyki

# %%
tips.describe(include=object)    # statystyki zm. kategorycznych (typ object)
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %% [markdown]
# ### Korelacje

# %%
tips.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# ### Wykresy w Pandas
#
# Metoda [plot()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html)
#
#
#
# Argument ``kind=`` określa rodzaj wykresu: ``line`` (default), ``bar``, ``hist``, ``box``, ``kde``, ``area``, ``pie``, ``scatter``
#
#
#
# Wykresy liniowe (domyślne) są robione tylko dla zmiennych numerycznych

# %%
# domyślnie os 'x' to indeksy Dataframe a oś 'y' to wartości zmiennych
tips.plot()
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Wykres ``plot()`` dla wybranych zmiennych
# * argumenty ``x='nazwa'`` i ``y='nazwa'``
# * wybór zmiennych z tablicy ``x['nazwa'].plot()``

# %%
tips.plot(y='tip', kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
tips['tip'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Wykres skrzynkowy**
#
# * ``Dataframe.plot(kind='box', ...)``
# * ``Dataframe.plot.box()``
# * ``DataFrame.boxplot()``

# %%
tips['tip'].plot(kind='box');

# %% [markdown]
# ### Grupowanie danych

# %%
print('Średnie wartości w grupie mężczyzn:')
tips[tips.sex == 'Male'][['tip', 'total_bill']].mean()
# Out:
# Średnie wartości w grupie mężczyzn:
# tip            3.089618
# total_bill    20.744076
# dtype: float64

# %% [markdown]
# Operacja grupowania `groupby()` pozwala w wygodny sposób wykonać operacje na grupach danych (np. wyznaczyć wartość średnią w grupach).
#
# Funkcje agregujące: ``mean(), min(), max(), count(), first()``, itd.

# %%
tips_mean = tips[ ['total_bill', 'tip', 'sex'] ].groupby(['sex']).mean()    # średnie wartości napiwków (tips) względem płci 
tips_mean                                                                   # wynik jest typu DataFrame
# Out:
#         total_bill       tip
# sex
# Female   18.056897  2.833448
# Male     20.744076  3.089618

# %%
tips_mean = tips[ ['tip', 'sex'] ].groupby(['sex']).mean()
tips_mean['tip'].plot(kind='bar', title='Mean tip');

# %% [markdown]
# Wyznaczmy liczebność próbek w grupie mężczyzn i kobiet (zmienna grupująca ``sex``)

# %%
tips_count = tips.groupby(['sex']).count()
display(tips_count)
tips_count.plot.pie(y='tip', autopct='%1.0f%%', legend=False,);
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Female          87   87      87   87    87    87
# Male           157  157     157  157   157   157

# %% [markdown]
# ## Pakiet Seaborn
#
# Seaborn to biblioteka do wizualizacji danych bazująca na matplotlib, która udostępnia zestaw narzędzi do tworzenia typowych wykresów używanych w statystyce i analizie danych. Źródłem danych dla wykresów Seaborn mogą być serie i tabele Pandas.
#
# WWW: <https://seaborn.pydata.org/>
# Tutorial: <https://seaborn.pydata.org/tutorial.html>
# Rodzaje dostepnych wykresów, API <https://seaborn.pydata.org/api.html>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(style="darkgrid")     # ustawienie stylu

# %%
tips = pd.read_csv('dane/tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Wykres rozkładu danych
#
# histogram, estymacja gęstości `displot(), histplot(), boxplot()`

# %%
# histogram z dopasowanymym wykresem rozkładu gęstości dla pojedynczej zmiennej
sns.displot(data=tips, x='total_bill', kde=True);

# %% [markdown]
# Wykres skrzynkowy `boxplot`

# %%
sns.boxplot(tips);

# %%
# wykres skrzynkowy w grupach utworzonych przez zmienną 'sex'
sns.boxplot(data=tips, y='tip', x='sex');

# %% [markdown]
# ### Wykresy relacji dwóch zmiennych

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip");  # wykres rozrzutu

# %% [markdown]
# Wykres rozrzutu z podziałem na grupy

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue='sex');  # grupy w różnych kolorach

# %% [markdown]
# Funkcja `relplot()` - ogólna funkcja do wizualizacji zależności pozwala również podzielić wykresy w kolumnach

# %%
sns.relplot(data=tips, x="total_bill", y="tip", col='sex', kind='scatter');

# %% [markdown]
# ### pairplot
#
# Wykres relacji wszystkich par zmiennych numerycznych

# %%
sns.pairplot(tips);

# %% [markdown]
# ### Ćwiczenie
#
# Dla danych ``tips`` użyj ``pairplot`` do wizualizacji róznic w rozkładzie danych w grupie mężczyzn i kobiet.
# _Wskazówka: argument ``hue`` pozwala wskazać zmienną kolorującą punkty_

# %%
import pandas as pd
import seaborn as sns
tips = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv')

# %% [markdown]
# ### regplot() - wykres z regresja liniową

# %%
sns.regplot(data=tips, x="total_bill", y="tip");

# %% [markdown]
# ### Korelacje (heatmp)

# %%
tips_corr = tips.corr(numeric_only=True)
sns.heatmap(data=tips_corr);

# %% [markdown]
# ### Wykresy zmiennych dyskretnych:

# %%
# wykres słópkowy liczby próbek w grupach 
sns.countplot(data=tips, x="sex");

# %%
# to samo w podziale na grupy 'time' 
# catplot() ogólna funkcja dla zmiennych kategorycznych, pozwala rozdzielić wykresy w kolumnach
sns.catplot(data=tips, kind="count", x="sex", col="time");

# %% [markdown]
# ## Zadanie: choroby serca
#
# Korzystając z pakietu Pandas oraz Seaborn wykonaj eksplorację danych dotyczących chorób serca zawartych w pliku:
# [dane/heart.csv](dane/heart.csv)
#
# Dane zawierają 303 przypadki opisane 12 zmiennymi. Ostatnia zmienna ``class`` zawiera informacje o występowaniu schorzenia serca (wartości `absence` (nie wystepuje), `presence` (występuje))
#
# 1. `age`  - wiek
# 2. `sex` - płeć (male, female)
# 3. `cp` -  rodzaj bólu klatki piersiowej (chest pain type: typical angina, atypical angina, non-anginal pain, asymptomatic)
# 4. `trestbps` -  ciśnienie krwi (resting blood pressure (in mm Hg on admission to the hospital))
# 5. `chol` -   cholesterol  (serum cholestoral in mg/dl )
# 6. `fbs` -   poziom cukru  we krwi (fasting blood sugar > 120 mg/dl (true or false) )
# 7. `restecg` - wynik badań kardiograficznych (normal, left_vent_hyper, st_t_wave_abnormality)
# 8. `thalac` -`maksymalne tętno
# 9. `exang` - angina wywołana wysiłkiem fizycznym (yes, no)
# 10. `oldpeak` -  głebokość odcinka ST na wykresie EKG (ST depression induced by exercise relative to rest)
# 11. `slope` -  nachylenie odcinka ST na wykresie EKG (the slope of the peak exercise ST segment (upsloping, flat, downsloping))
# 12. `class`  - przewidywana wartość, występowanie schorzenia (absence, presence)

# %% [markdown]
# 1. Zaimportuj dane do tablicy `DataFrame` i wyświetl informację zawierającą nazwy zmiennych, liczbę przypadków oraz typy zmiennych (np. typ kategoryczny `object`, numeryczny `float64`)

# %%
df = pd.read_csv(r"dane\heart.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    object
#  2   cp        303 non-null    object
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    object
#  6   restecg   303 non-null    object
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    object
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    object
#  11  class     303 non-null    object
# dtypes: float64(5), object(7)
# memory usage: 28.5+ KB

# %% [markdown]
# 2. Dla zmiennych kategorycznych (typu `object`) uzyskaj nastepujące statystyki opisowe:
# * liczbę unikatowych wartości `unique`
# * wartość najczęścięj wystepującą `top`
# * liczbę wytąpień najczęściej występującej wartości `freq`
#
# Następnie dla zmiennej `class` wyznacz stosunek `freq` do liczby wszystkich pacjentów w danych. Jest do poziom poprawności klasyfikacji naiwnej reguły przypisującej każdego pacjenta do klasy większościowej (najczęściej występuącej, `top`).

# %%
df.select_dtypes(include='object').describe()

class_desc = df['class'].describe()

unique = class_desc['unique']
top = class_desc['top']
freq = class_desc['freq']
count = len(df)

ratio = freq / count

print(f"Liczba unikatowych wartości: {unique}")
print(f"Najczęstsza wartość: {top}")
print(f"Liczba wystąpień: {freq}")
print(f"Poziom poprawności klasyfikacji naiwnej: {ratio:.2f}")
# Out:
# Liczba unikatowych wartości: 2
# Najczęstsza wartość: absence
# Liczba wystąpień: 165
# Poziom poprawności klasyfikacji naiwnej: 0.54

# %% [markdown]
# 3. Użyj wykresu [pairplot()](https://seaborn.pydata.org/generated/seaborn.pairplot.html#seaborn.pairplot) do zobrazowania różnic w rozkładzie danych pacjentów zdrowych i chorych (zmienna `class=['absebce', 'presence']`).
# Wykres sporządź dla wszystkich zmiennych numerycznych, w taki sposób aby punkty oznaczające pacjentów chorych różniły się kolorem od punktów oznaczających pacjentów zdrowych

# %%
sns.pairplot(df, hue='class', diag_kind='hist', 
             vars=df.select_dtypes(include='float64').columns)


plt.show()

# %% [markdown]
# 4. Na podstawie wykresu uzyskanego w poprzednim kroku wybierz pojedyńczą zmienną numeryczną, która najlepiej separuje obie grupy pacjentów. Wyznacz wartość średnią tej zmiennej w grupie chorych (``presence``) i w grupie zdrowych (``absence``).

# %%
mean_val = df.groupby('class')['thalach'].mean()

print("Średnie wartości zmiennej 'thalach':")
print(mean_val)
# Out:
# Średnie wartości zmiennej 'thalach':
# class
# absence     158.466667
# presence    139.101449
# Name: thalach, dtype: float64

# %% [markdown]
# 5. Korzystając ze zmiennej wybranej w poprzednim punkcie zaproponuj regułę decyzyjną, która pozwoli przypisać dowolnego pacjenta do grupy chorych (`presence`) lub zdrowych (`absence`). Dodaj do tablicy danych zmienną `diagnoza` o wartościach `presence` lub `absence` uzyskanych zgodnie z zaproponowaną regułą zastosowaną do pacjentów ze zbioru danych. Wyznacz poprawność klasyfikacji zaproponowanej reguły obliczając ułamek poprawnie zdiagnozowanych pacjentów (liczba zgodnych wartości zmiennych `diagnoza` i zmiennej `class`) do liczby wszystkich 303 przypadków. Skuteczna reguła powinna posiadać istotnie wyższą poprawność w porównaniu do naiwnej reguły z punktu 2 zadania.

# %%
prog = (158.47 + 139.10) / 2

df['diagnoza'] = df['thalach'].apply(lambda x: 'presence' if x < prog else 'absence')


poprawne = (df['diagnoza'] == df['class']).sum()
poprawnosc = poprawne / len(df)

print(f"Poprawnie sklasyfikowanych przypadków: {poprawne} z {len(df)}")
print(f"Poprawność klasyfikacji: {poprawnosc:.3f}")
# Out:
# Poprawnie sklasyfikowanych przypadków: 213 z 303
# Poprawność klasyfikacji: 0.703
