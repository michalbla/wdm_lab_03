# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Wprowadzenie-do-Pandas-i-Seaborn" data-toc-modified-id="Wprowadzenie-do-Pandas-i-Seaborn-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Wprowadzenie do Pandas i Seaborn</a></span><ul class="toc-item"><li><span><a href="#Pandas" data-toc-modified-id="Pandas-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Pandas</a></span></li><li><span><a href="#Series-i-DataFrame" data-toc-modified-id="Series-i-DataFrame-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Series i DataFrame</a></span></li><li><span><a href="#Series" data-toc-modified-id="Series-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Series</a></span></li><li><span><a href="#DataFrame" data-toc-modified-id="DataFrame-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>DataFrame</a></span><ul class="toc-item"><li><span><a href="#Indeksowanie-tablic-DataFrame" data-toc-modified-id="Indeksowanie-tablic-DataFrame-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Indeksowanie tablic DataFrame</a></span></li><li><span><a href="#Operacje-arytmetyczne-i-funkcje-NumPy" data-toc-modified-id="Operacje-arytmetyczne-i-funkcje-NumPy-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Operacje arytmetyczne i funkcje NumPy</a></span></li></ul></li><li><span><a href="#Funkcje-statystyczne" data-toc-modified-id="Funkcje-statystyczne-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Funkcje statystyczne</a></span></li><li><span><a href="#Ćwiczenie" data-toc-modified-id="Ćwiczenie-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Ćwiczenie</a></span><ul class="toc-item"><li><span><a href="#Import-danych-z-plików-CSV" data-toc-modified-id="Import-danych-z-plików-CSV-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Import danych z plików CSV</a></span></li><li><span><a href="#Informacje-o-nazwie-i-typie-zmiennych-(kolumn)" data-toc-modified-id="Informacje-o-nazwie-i-typie-zmiennych-(kolumn)-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>Informacje o nazwie i typie zmiennych (kolumn)</a></span></li><li><span><a href="#Podstawowe-statystyki-opisowe:-describe()" data-toc-modified-id="Podstawowe-statystyki-opisowe:-describe()-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>Podstawowe statystyki opisowe: describe()</a></span></li><li><span><a href="#Korelacje" data-toc-modified-id="Korelacje-1.6.4"><span class="toc-item-num">1.6.4&nbsp;&nbsp;</span>Korelacje</a></span></li><li><span><a href="#Wykresy-,-metoda-plot()" data-toc-modified-id="Wykresy-,-metoda-plot()-1.6.5"><span class="toc-item-num">1.6.5&nbsp;&nbsp;</span>Wykresy , metoda plot()</a></span></li><li><span><a href="#Ćwiczenie" data-toc-modified-id="Ćwiczenie-1.6.6"><span class="toc-item-num">1.6.6&nbsp;&nbsp;</span>Ćwiczenie</a></span></li><li><span><a href="#Grupowanie-danych" data-toc-modified-id="Grupowanie-danych-1.6.7"><span class="toc-item-num">1.6.7&nbsp;&nbsp;</span>Grupowanie danych</a></span></li></ul></li><li><span><a href="#Pakiet-Seaborn" data-toc-modified-id="Pakiet-Seaborn-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Pakiet Seaborn</a></span><ul class="toc-item"><li><span><a href="#Wykres-rozkładu-danych" data-toc-modified-id="Wykres-rozkładu-danych-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>Wykres rozkładu danych</a></span></li><li><span><a href="#Wykresy-relacji-dwóch-zmiennych" data-toc-modified-id="Wykresy-relacji-dwóch-zmiennych-1.7.2"><span class="toc-item-num">1.7.2&nbsp;&nbsp;</span>Wykresy relacji dwóch zmiennych</a></span></li><li><span><a href="#pairplot" data-toc-modified-id="pairplot-1.7.3"><span class="toc-item-num">1.7.3&nbsp;&nbsp;</span>pairplot</a></span></li><li><span><a href="#Ćwiczenie" data-toc-modified-id="Ćwiczenie-1.7.4"><span class="toc-item-num">1.7.4&nbsp;&nbsp;</span>Ćwiczenie</a></span></li><li><span><a href="#regplot()---wykres-z-regresja-liniową" data-toc-modified-id="regplot()---wykres-z-regresja-liniową-1.7.5"><span class="toc-item-num">1.7.5&nbsp;&nbsp;</span>regplot() - wykres z regresja liniową</a></span></li><li><span><a href="#Korelacje-(heatmp)" data-toc-modified-id="Korelacje-(heatmp)-1.7.6"><span class="toc-item-num">1.7.6&nbsp;&nbsp;</span>Korelacje (heatmp)</a></span></li><li><span><a href="#Wykresy-zmiennych-dyskretnych:" data-toc-modified-id="Wykresy-zmiennych-dyskretnych:-1.7.7"><span class="toc-item-num">1.7.7&nbsp;&nbsp;</span>Wykresy zmiennych dyskretnych:</a></span></li></ul></li><li><span><a href="#Zadanie:-choroby-serca" data-toc-modified-id="Zadanie:-choroby-serca-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Zadanie: choroby serca</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Wprowadzenie do Pandas i Seaborn

# %% [markdown]
# ## Pandas
#
# Pakiet Pandas udostępnia dwa obiekty służące do wygodnego przechowywania danych i ułatwiających manipulowanie danymi:
# * **Series** to obiekt reprezentujący jednowymiarową tablicę danych
# * **DataFrame** to dwu-wymiarowa tabela danych (zbiór obiektów series)
#
# Pandas WWW: <https://pandas.pydata.org/>
# Pandas Tutorial: <https://pandas.pydata.org/docs/getting_started/intro_tutorials/index.html>

# %% [markdown]
# ## Series i DataFrame

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Series
#
# Seria jest obiektem reprezentującym jednowymiarową tablicę danych, której elementy są indeksowane. Seria może być utworzona z dowolnej kolekcji liczb: krotki, listy, tablicy numpy a nawet ze słownika. Obiekt Series udostępnia wiele metod pozwalających operować na danych w serii, zawiera też  metody do wizualizowania danych. Dodatkowo, wiele funkcji z pakietu numpy może byc użytych na tym obiekcie, jeżeli tylko seria zawiera liczby.

# %%
import pandas as pd

s = pd.Series([3.1, 2.4, -1.7, 0.2, -2.9, 4.5])   # seria utworzona z listy liczb

print(s)
print('Values=', s.values, type(s.values))     # wartości serii (obiekt ndarray z NumPy)
print('Index=', s.index)       # indeksy  serii 
print('Pierwszy element:', s[0])

# %% [markdown]
# W odróżnieniu do tablic indeksami nie muszą być liczby całkowite.

# %%
import numpy as np

s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
s

# %%
print('Values=', s.values)   # wartości, to tablica numpy
print('Index=', s.index)     # indeksy

# %%
print(s['a'])     # indeksowanie za pomocą napisów
print(s[0])       # indeksowanie liczbami całkowitymi nadal działa

# %% [markdown]
# Obiekt Series w wielu sytuacjach zachowuje się podobnie do tablic NumPy.
# W podobny sposób indeksuje się elementy serii, z tą różnicą, że przekroje również dotyczą indeksów.

# %%
s = pd.Series([1.2, 2.5, -2.2, 3.1, -0.8], 
            index = ['pn','wt','śr','czw','pt'])
s

# %%
s[1:3]          # przekrój serii (elementy od 1 do 2)

# %%
s['wt':'czw']    # elementy od wt do czw (zauważ, że ostatni element 'czw' też jest włączony)

# %% [markdown]
# Gdy seria zawiera wartości numeryczne to można wykonywać na niej operacje arytmetyczne i funkcje NumPy

# %%
s = s +  4
s

# %%
s = np.sqrt(s)
s

# %% [markdown]
# ## DataFrame
#
# Obiekt `DataFrame` reprezentuje 2-wymiarową tabelę danych, która posiada indeksowane kolumny oraz wiersze.
# Każda kolumna to obiekt Series. Kolumna reprezentuje zmienną i może zawierać elementy różnego typu (liczby, wartości kategoryczne, napisy, serie czasowe, itd.).
#
# <div>
# <img src="attachment:4f98748b-7f54-4401-852b-369c5ffa1c7e.png" width="600">
# </div>
#
# Tablica DataFrame posiada wiele przydatnych metod ułatwiających operowanie danymi, wyznaczanie statystyk i sporządzenie wykresów.
#
# Zobacz: <https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html>

# %% [markdown]
# Tworzenie tablic DataFrame (np. z tablicy numpy)

# %%
df = pd.DataFrame(np.random.rand(4,3), columns=['zmienna 1', 'zmienna 2', 'zmienna 3'])
display(df)

# %%
print('Values=', df.values, type(df.values))     # wartości tabeli,ndarray z NumPy)
print('Index=',  df.index)      
print('Columns:', df.columns)

# %% [markdown]
# Kolumny (zmienne) indeksowane są za pomocą nazw zmiennych

# %%
df['zmienna 2']   # wynikiem jest seria

# %% [markdown]
# Kolumna tabeli jest obiektem Series

# %%
type(df['zmienna 2'])

# %% [markdown]
# Dodawanie nowych kolumn w tabeli przypomina dodawanie nowych elementów do słownika.

# %%
df['rok'] = 2021                              # dodanie kolumny ze stałą wartością
df

# %%
df['x1'] = np.random.rand(4)   
df['liczby'] = ['raz', 'dwa', 'trzy', 'cztery']
df['zm1+zm2'] = df['zmienna 1'] + df['zmienna 2']
df

# %% [markdown]
# Wybór kilku zmiennych

# %%
df[ ['rok','zmienna 1'] ]

# %% [markdown]
# Wynik jest typu DataFrame  - otrzymujemy nowy widok tabeli

# %%
type(df[['zmienna 1','rok']])

# %% [markdown]
# Kolumna (seria) dostępna jest też w poprzez atrybut obiektu DataFrame o tej samej nazwie co nazwa zmiennej

# %%
df.rok           # to samo co df['rok']

# %%
df.liczby[2:]

# %% [markdown]
# ### Indeksowanie tablic DataFrame
#
# * atrybut `iloc[]` - indeksowanie za pomocą __liczb całkowitych__ (lub macierzy boolowskich) identycznie jak w NumPy
# * atrybut `loc[]` - indeksowanie za pomocą etykiet (indeks, nazwy zmiennych) oraz macierzy boolowskich

# %%
display(df)

df.iloc[2]    # wiersz 3, wynikiem jest seria elementów wiersza, elementy moga być różnego typu

# %%
df.iloc[2 ,1]    # 3 wiersz, 2 kolumna

# %% [markdown]
# Indeksowanie zakresów dwukropkiem : podobnie jak w NumPy

# %%
display(df)
df.iloc[:, 2]   # trzecia kolumna tabeli -> wynikiem jest seria

# %%
df.iloc[:2, 1:3]     # przekrój danych (wiersze 0,1,2 i kolumny 1,2) -> wynik DataFrame

# %%
df.loc[2]    # tu indeksy są liczbami, więc działa tak samo jak iloc[]

# %%
df.loc[:2]    # zauważ, że loc[] uwzględnia ostatni element indeksowania

# %%
df.loc[:2, 'rok':'x1']

# %%
df.loc[:2, ['rok', 'x1']]

# %% [markdown]
# Filtrowanie za pomocą wyrażeń logicznych

# %%
df[ df['x1'] < 0.6 ]

# %%
df[ (df.x1 < 0.6) | (df.liczby == "trzy") ]

# %% [markdown]
# ###  Operacje arytmetyczne i funkcje NumPy
#
# Jeżeli tablica zawiera dane liczbowe to można na nich wykonywać operacje arytmetyczne a nawet metody numpy.

# %%
data = pd.DataFrame(np.random.rand(5, 3), columns=['x1', 'x2', 'x3'])
data

# %%
print('Transpozycja:') 
data.T

# %%
print('Dodawanie:')
data + 4      # dodawanie liczby do wszystkich elementów

# %%
print('Mnożenie:')
data * 10   # mnożenie

# %%
print('np.exp():')
np.exp(data)   # exp() dla wszystkich elementów

# %% [markdown]
# ## Funkcje statystyczne
#
# ``mean()``, ``std``, ``median()``, ``min()``, ``max()``, itd.

# %%
display(data)

print('Min  ', data.min())

# %% [markdown]
# ## Ćwiczenie
#
# Wyznacz wsp. prostej dopasowanej do danych z zadania z pierwszych zajęć używając danych umieszczonych w DataFrame.

# %%
x = [ 8, 2, 11, 6, 5, 4, 12, 9, 6, 1 ]
y = [ 3, 10, 3, 6, 8, 12, 1, 4, 9, 14 ]

# %% [markdown]
# ### Import danych z plików CSV
#
# ![image.png](attachment:image.png)

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv')
tips

# %% [markdown]
# ### Informacje o nazwie i typie zmiennych (kolumn)

# %%
tips.info()     # informacje o zmiennych

# %%
tips.head()     # podgląd początku tabeli

# %% [markdown]
# ### Podstawowe statystyki opisowe: describe()

# %%
tips.describe()   # domyślnie wynik tylko dla zmiennych liczbowych (ciągłych)

# %% [markdown]
# Dla zmiennych nie numerycznych (``object``) przydatne są inne statystyki

# %%
import numpy as np
tips.describe(include=object)    # statystyki zm. nominalnych (typ object)

# %% [markdown]
# ### Korelacje

# %%
tips.corr(numeric_only=True)

# %% [markdown]
# ### Wykresy , metoda plot()
#
# Rodzaje wykresów, argument `kind=`
#   `'line'` (default), `'bar'`, `'hist'`, `'box'`, `'kde'`, `'area'`, `'pie'`, `'scatter'`
#
# Wykresy są robione tylko dla zmiennych numerycznych

# %%
# wykres liniowy, domyślnie os x to indeksy Dataframe
tips.plot()
tips.head()

# %% [markdown]
# **Wykres rozrzutu (punktowy)**

# %%
tips.plot.scatter(x='total_bill', y='tip', title='Wykres rozrzutu');

# %% [markdown]
# **Histogram**

# %%
tips.plot.hist(y = 'total_bill', title='Histogram');

# %% [markdown]
# ### Ćwiczenie
#
# Wyświetl histogramy zmienneych numerycznych dla danych z grupy mężczyzn (``sex == Male``).
# _Wskazowka: argumement ``subplots=True`` wyodrębnia podwykresy dla każdej zmiennej._

# %% [markdown]
# **Wykres skrzynkowy**

# %%
tips.plot(kind='box');

# %% [markdown]
# ### Grupowanie danych

# %%
print('Średnie wartości w grupie mężczyzn:')
tips[tips.sex == 'Male'][['tip', 'total_bill']].mean()

# %% [markdown]
# Operacja grupowania `groupby()` pozwala w wygodny sposób wykonać operacje na grupach danych (np. wyznaczyć wartość średnią w grupach).
#
# Funkcje agregujące: ``mean(), min(), max(), count(), first()``, itd.

# %%
tips_mean = tips.groupby(['sex']).mean()    # średnie wartości napiwków (tips) względem płci 
tips_mean  # wynik jest typu DataFrame

# %%
tips_mean['tip'].plot.bar();

# %% [markdown]
# Wyznaczmy liczebność próbek w grupie mężczyzn i kobiet (zmienna grupująca ``sex``)

# %%
tips_count = tips.groupby(['sex']).count()
display(tips_count)
tips_count.plot.pie(y='tip', autopct='%1.0f%%', legend=False,);

# %% [markdown]
# ## Pakiet Seaborn
#
# Seaborn to biblioteka do wizualizacji danych bazująca na matplotlib, która udostępnia zestaw narzędzi do tworzenia typowych wykresów używanych w statystyce i analizie danych. Źródłem danych dla wykresów Seaborn mogą być serie i tabele Pandas.
#
# WWW: <https://seaborn.pydata.org/>
# Tutorial: <https://seaborn.pydata.org/tutorial.html>
# Rodzaje dostepnych wykresów, API <https://seaborn.pydata.org/api.html>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(style="darkgrid")     # ustawienie stylu

# %%
tips = pd.read_csv('dane/tips.csv')
tips.head()

# %% [markdown]
# ### Wykres rozkładu danych
#
# histogram, estymacja gęstości `displot(), histplot(), boxplot()`

# %%
# histogram z dopasowanymym wykresem rozkładu gęstości dla pojedynczej zmiennej
sns.displot(data=tips, x='total_bill', kde=True);

# %% [markdown]
# Wykres skrzynkowy `boxplot`

# %%
sns.boxplot(tips);

# %%
# wykres skrzynkowy w grupach utworzonych przez zmienną 'sex'
sns.boxplot(data=tips, y='tip', x='sex');

# %% [markdown]
# ### Wykresy relacji dwóch zmiennych

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip");  # wykres rozrzutu

# %% [markdown]
# Wykres rozrzutu z podziałem na grupy

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue='sex');  # grupy w różnych kolorach

# %% [markdown]
# Funkcja `relplot()` - ogólna funkcja do wizualizacji zależności pozwala również podzielić wykresy w kolumnach

# %%
sns.relplot(x="total_bill", y="tip", data=tips, col='sex', kind='scatter');

# %% [markdown]
# ### pairplot
#
# Wykres relacji wszystkich par zmiennych numerycznych

# %%
sns.pairplot(tips);

# %% [markdown]
# ### Ćwiczenie
#
# Uzyj ``pairplot`` do wizualizacji róznic w rozkładzie danych dla mężczyzn i kobiet.
# _Wskazówka: argument ``hue`` pozwala wskazać zmienną kolorującą punkty_

# %% [markdown]
# ### regplot() - wykres z regresja liniową

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %% [markdown]
# ### Korelacje (heatmp)

# %%
sns.heatmap(tips.corr(numeric_only=True));

# %% [markdown]
# ### Wykresy zmiennych dyskretnych:

# %%
# wykres słópkowy liczby próbek w grupach 
sns.countplot(data=tips, x="sex");

# %%
# to samo w podziale na grupy 'time' 
# catplot() ogólna funkcja dla zmiennych kategorycznych, pozwala rozdzielić wykresy w kolumnach
sns.catplot(data=tips, kind="count", x="sex", col="time");

# %% [markdown]
# ## Zadanie: choroby serca
#
# Korzystając z pakietu Pandas oraz Seaborn wykonaj eksplorację danych dotyczących chorób serca zawartych w pliku:
# [dane/heart-cleveland.csv](dane/heart-cleveland.csv)
#
# Dane zawierają 303 przypadki opisane 12 zmiennymi. Ostatnia zmienna zawiera informacje o występowaniu schorzenia serca (wartości `absence`, `presence`)
#
# 1. `age`  - wiek
# 2. `sex` - płeć (male, female)
# 3. `cp` -  rodzaj bólu klatki piersiowej (chest pain type: typical angina, atypical angina, non-anginal pain, asymptomatic)
# 4. `trestbps` -  ciśnienie krwi (resting blood pressure (in mm Hg on admission to the hospital))
# 5. `chol` -   cholesterol  (serum cholestoral in mg/dl )
# 6. `fbs` -   poziom cukru  we krwi (fasting blood sugar > 120 mg/dl (true or false) )
# 7. `restecg` - wynik badań kardiograficznych (normal, left_vent_hyper, st_t_wave_abnormality)
# 8. `thalac` -`maksymalne tętno
# 9. `exang` - angina wywołana wysiłkiem fizycznym (yes, no)
# 10. `oldpeak` -  głebokość odcinka ST na wykresie EKG (ST depression induced by exercise relative to rest)
# 11. `slope` -  nachylenie odcinka ST na wykresie EKG (the slope of the peak exercise ST segment (upsloping, flat, downsloping))
# 12. `class`  - przewidywana wartość, występowanie schorzenia (absence, presence)

# %% [markdown]
# 1. Zaimportuj dane do tablicy DataFrame i wyświetl informacje zmiennych (funkcja ``info()``)

# %% [markdown]
# 2. Wyodrębnij zbiór danych zawierający wyłacznie zmienne ``age``, ``trestbps``, ``chol``, ``thalach``, ``class``

# %% [markdown]
# 3. Wyświetl podstawowe statystyki opisowe (``min``, ``max``, ``mean``, ``std``) dla wszystkich zmiennych numerycznych

# %% [markdown]
# 4.  Użyj wykresu [pairplot()](https://seaborn.pydata.org/generated/seaborn.pairplot.html#seaborn.pairplot) do zobrazowania różnic w rozkładzie danych pacjentów zdrowych i chorych (zmienna `class=['absebce', 'presence']`). Grupy pacjentów powinny być wyraźnie wyróżnione (np. kolorem)

# %% [markdown]
# 5. Na podstawie poprzedniego wykresu wybierz parę zmiennych, która najlepiej separuje obie grupy.
# Dla wybranej pary zmiennych wyznacz wartość średnią w grupie chorych (``presence``) i w grupie zdrowych (``absence``).
